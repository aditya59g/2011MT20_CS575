# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as pdr
from datetime import datetime
import matplotlib.pyplot as plt 
from statsmodels.tsa.stattools import adfuller,kpss
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import warnings
warnings.simplefilter('ignore')

# %%
#download data
aapl = pdr.DataReader('AAPL', 'yahoo', start=datetime(2014, 8, 1), end=datetime(2016, 11, 30))

# %%
aapl.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2014-08-01  24.155001  23.702499  23.725000  24.032499  194044000.0  21.657644
# 2014-08-04  24.145000  23.792500  24.092501  23.897499  159832000.0  21.535982
# 2014-08-05  23.920000  23.590000  23.840000  23.780001  223732000.0  21.430096
# 2014-08-06  23.870001  23.677500  23.687500  23.740000  154232000.0  21.394049
# 2014-08-07  23.987499  23.525000  23.732500  23.620001  186844000.0  21.391787

# %%
#export and save as csv files
aapl.to_csv('Apple_stock.csv', sep=',')

# %%
plt.figure(figsize=(16,8))
plt.plot(aapl['Close'], label='Close Price history')
plt.legend()
plt.title('Original Data')
# Out:
# Text(0.5, 1.0, 'Original Data')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(aapl["Close"], model='multiplicative', freq = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(10, 8)

# %%
def adf_test(atr):
    #Perform Dickey-Fuller test:
    timeseries = aapl[atr].dropna()
    print ('Results of Dickey-Fuller Test for ',atr,'\n')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

#apply adf test on the series
adf_test('Close')
# Out:
# Results of Dickey-Fuller Test for  Close
#
# Test Statistic                  -2.170605
# p-value                          0.217087
# #Lags Used                       0.000000
# Number of Observations Used    588.000000
# Critical Value (1%)             -3.441520
# Critical Value (5%)             -2.866468
# Critical Value (10%)            -2.569394
# dtype: float64

# %% [markdown]
# ADF test: The test statistic is greater than the critical value, so we fail to reject the null hypothesis. So it is non-stationary series. Also P value is greater than 0.05 so, from that also we can say it in non-stationary.

# %%
def kpss_test(atr):
    timeseries = aapl[atr].dropna()
    print ('Results of KPSS Test for ',atr)
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
        kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)
kpss_test('Close')
# Out:
# Results of KPSS Test for  Close
# Test Statistic            0.655743
# p-value                   0.017569
# Lags Used                19.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64

# %% [markdown]
# KPSS Test: The test statistic is greater than the critical value so we can reject the null hypothesis. So it is non-stationary series.

# %%
plot_acf(aapl['Close'].dropna(), lags=10)
plt.show()
plot_pacf(aapl['Close'].dropna(), lags=10)
plt.show()

# %% [markdown]
# From ACF plot also, we can see that at each lag autocorelation decreasing slowly. So data is non stationary and to make it stationary we can use differencing method.
#
# Here, I have used simple differencing and plotted the acf,pacf again to see status of stationarity.

# %%
aapl['Diff'] = aapl['Close'].diff(periods=1)

# %%
adf_test('Diff')
# Out:
# Results of Dickey-Fuller Test for  Diff
#
# Test Statistic                 -23.776321
# p-value                          0.000000
# #Lags Used                       0.000000
# Number of Observations Used    587.000000
# Critical Value (1%)             -3.441539
# Critical Value (5%)             -2.866476
# Critical Value (10%)            -2.569399
# dtype: float64

# %%
kpss_test('Diff')
# Out:
# Results of KPSS Test for  Diff
# Test Statistic            0.130863
# p-value                   0.100000
# Lags Used                19.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64

# %%
plot_acf(aapl['Diff'].dropna(), lags=10)
plt.show()
plot_pacf(aapl['Diff'].dropna(), lags=10)
plt.show()

# %% [markdown]
# ## **ARIMA Model**

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
# !pip3 install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (1.8.2)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (56.0.0)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.22)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels!=0.12.0,>=0.11->pmdarima) (1.15.0)

# %%
data = aapl['Close'].to_numpy()
train = data[:int(len(data)*0.8)]
test = data[int(len(data)*0.8):]
date = (aapl.index)

# %%
import pmdarima as pm
st_model = pm.auto_arima(train, start_p=1, start_q=1,max_p=3, max_q=3, m=1,start_P=0, seasonal=False,d=1, D=0, trace=True,error_action='ignore',suppress_warnings=True,stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=584.728, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=581.226, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=583.224, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=583.224, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=579.227, Time=0.03 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.839 seconds

# %%
model=ARIMA(data,order=(1,1,1))
model_fit = model.fit()

# %%
forecast = model_fit.predict(typ='levels')

# %%
rmse1 = np.sqrt(np.mean(np.power((np.array(test[1:])-np.array(forecast[int(len(data)*0.8):])),2)))
print('RMSE value using ARIMA model',rmse1)
# Out:
# RMSE value using ARIMA model 0.3395204276219951

# %%
plt.figure(figsize=(16,8))
plt.plot(date,data, label='Original Data')
plt.plot(date[:int(0.8*len(data))],forecast[:int(0.8*len(data))], label='Predicted Data')
plt.plot(date[int(0.8*len(data))+1:],forecast[int(0.8*len(data)):], label='Predicted Data(20%)')
plt.legend()
plt.title('Prediction using ARIMA')
# Out:
# Text(0.5, 1.0, 'Prediction using ARIMA')

# %% [markdown]
# ### Fitting only train data to the ARIMA model

# %%
model0 = ARIMA(train,order=(1,1,1))
model_fit0 = model0.fit()

# %%
forecast0 = model_fit0.predict(len(train),len(train)+len(test)-1,typ='levels')

# %%
rmse0 = np.sqrt(np.mean(np.power((np.array(test)-np.array(forecast0)),2)))
print('RMSE value using ARIMA model (train data only): ',rmse0)
# Out:
# RMSE value using ARIMA model (train data only):  2.9580930287633276

# %%
plt.figure(figsize=(16,8))
plt.plot(date,data, label='Original Data')
plt.plot(date[int(0.8*len(data)):],forecast0, label='Predicted Data')
plt.legend()
plt.title('Prediction using ARIMA')
# Out:
# Text(0.5, 1.0, 'Prediction using ARIMA')

# %% [markdown]
# ## **Exponential Smoothing**

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
n = int(len(aapl["Close"])*0.8)
data = aapl['Close'].to_numpy()
train2 = data[:n]
test2 = data[n:]
date = (aapl.index)

# %%
Exp_model = ExponentialSmoothing(aapl.Close,trend='mul',seasonal='mul',seasonal_periods=4)
aapl['Pred_Exp'] = Exp_model.fit(smoothing_level = 0.9,smoothing_slope= 0.1,smoothing_seasonal = 0.2).fittedvalues.shift(0)

# %%
rmse2 = np.sqrt(np.mean(np.power((np.array(test2)-np.array(aapl.Pred_Exp[n:])),2)))
print('RMSE value using Exponential Smoothing model: ',rmse2)
# Out:
# RMSE value using Exponential Smoothing model:  0.38593020411348894

# %%
plt.figure(figsize=(16,8))
plt.plot(date,data, label='Original Data')
plt.plot(date[:n],aapl.Pred_Exp[:n], label='Predicted Data')
plt.plot(date[n:],aapl.Pred_Exp[n:], label='Predicted Data(20%)')
plt.legend()
plt.title('Prediction using Exponential Smoothing')
# Out:
# Text(0.5, 1.0, 'Prediction using Exponential Smoothing')

# %% [markdown]
# ## **LSTM Model**

# %%
#importing required libraries
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

# %%
df1=aapl['Close']
date = (aapl.index)

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
##splitting dataset into train and test split
training_size = int(0.8*len(df1))
test_size = len(df1)-training_size
train_data = df1[0:training_size]
test_data = df1[training_size:len(df1)]

# %%
# convert an array of values into a dataset matrix 
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0]) 
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 5
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 100, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 5, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 100, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 5, 1).
# 6/8 [=====================>........] - ETA: 0s - loss: 0.2912 WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 100, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 5, 1).
# 8/8 [==============================] - 6s 222ms/step - loss: 0.2812 - val_loss: 0.0822
# Epoch 2/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1227 - val_loss: 0.0190
# Epoch 3/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0361 - val_loss: 0.0184
# Epoch 4/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0219 - val_loss: 0.0092
# Epoch 5/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0232 - val_loss: 0.0107
# Epoch 6/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0155 - val_loss: 0.0088
# Epoch 7/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0111 - val_loss: 0.0048
# Epoch 8/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0085 - val_loss: 0.0047
# Epoch 9/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0075 - val_loss: 0.0040
# Epoch 10/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 0.0037
# Epoch 11/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0047
# Epoch 12/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0058 - val_loss: 0.0038
# Epoch 13/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 14/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0058 - val_loss: 0.0039
# Epoch 15/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 16/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0040
# Epoch 17/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 18/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0058 - val_loss: 0.0040
# Epoch 19/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 20/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0037
# Epoch 21/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0058 - val_loss: 0.0038
# Epoch 22/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 23/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 24/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0060 - val_loss: 0.0038
# Epoch 25/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0038
# Epoch 26/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 27/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 28/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 29/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0037
# Epoch 30/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 31/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0056 - val_loss: 0.0036
# Epoch 32/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 33/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 34/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0040
# Epoch 35/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 0.0036
# Epoch 36/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0034
# Epoch 37/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0043
# Epoch 38/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0064 - val_loss: 0.0035
# Epoch 39/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0062 - val_loss: 0.0038
# Epoch 40/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 41/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 42/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 43/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0037
# Epoch 44/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 45/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 46/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 47/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0034
# Epoch 48/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0039
# Epoch 49/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 50/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 51/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0034
# Epoch 52/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0054 - val_loss: 0.0039
# Epoch 53/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 54/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 55/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 56/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 57/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0033
# Epoch 58/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0037
# Epoch 59/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 60/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 61/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 62/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 63/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 0.0034
# Epoch 64/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0035
# Epoch 65/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 66/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0037
# Epoch 67/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0057 - val_loss: 0.0039
# Epoch 68/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 69/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0037
# Epoch 70/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 71/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 72/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 73/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 74/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 75/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 76/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0032
# Epoch 77/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0046 - val_loss: 0.0032
# Epoch 78/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0032
# Epoch 79/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 80/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 81/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 82/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 83/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 84/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0032
# Epoch 85/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 86/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 87/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 88/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 89/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0031
# Epoch 90/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0032
# Epoch 91/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 92/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0031
# Epoch 93/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 94/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0031
# Epoch 95/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 96/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 97/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0030
# Epoch 98/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 99/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0031
# Epoch 100/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0033

# %%
# prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 100, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 5, 1).

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
Y_train = scaler.inverse_transform(y_train.reshape(-1, 1))
Y_test = scaler.inverse_transform(ytest.reshape(-1, 1))

# %%
# Train data RMSE
rmse3 = np.sqrt(np.mean(np.power((np.array(Y_train)-np.array(train_predict)),2)))
print('RMSE value of train data using LSTM model',rmse3)
# Out:
# RMSE value of train data using LSTM model 0.7925015522618483

# %%
# Test Data RMSE
rmse4 = np.sqrt(np.mean(np.power((np.array(Y_test)-np.array(test_predict)),2)))
print('RMSE value of test data using LSTM model',rmse4)
# Out:
# RMSE value of test data using LSTM model 0.6171199441917113

# %%
# plot baseline and predictions
look_back=5
plt.figure(figsize=(16,8))
plt.plot(date,scaler.inverse_transform(df1), label='Original Data')
plt.plot(date[look_back+1:training_size],train_predict, label='Train Data Prediction')
plt.plot(date[training_size+look_back+1:],test_predict, label='Test Data Prediction')
plt.legend()
plt.title('Prediction using LSTM')
plt.show()

# %% [markdown]
# ## **Inference**

# %% [markdown]
# For a taken parameter, RMSE value on test data using
#
# (1) ARIMA Model: 0.339520427471949
#
# (2) Exponential Smoothing: 0.3859302041134889
#
# (3) LSTM: 0.6171199441917113
#
#  So from this and plot we can say that ARIMA predicts better for a given parametr. In actual, above sentence can not be said. Statistical models like ARIMA , Exponential smoothing are not training the model like DL,ML model.
#
#  Also, if we give high time-step in LSTM, It can predict much more accurate. So from  this conclusion is that deep learning models can be improved and can predict efficiently compare to stats model.
